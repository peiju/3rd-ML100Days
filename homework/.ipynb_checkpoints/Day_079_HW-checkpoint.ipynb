# %% [markdown]
# ## Work
# 1. 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現

# %%
import os
import keras

# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若想使用可自行開啟)
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
# 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現
LEARNING_RATE = 0.01
EPOCHS = 5
BATCH_SIZE = 256
MOMENTUM = [0.95, 0.85, 0.75]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for mom in MOMENTUM:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with MOMENTUM = %.2f" % (mom))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=mom)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-MOMENTUM-%s" % str(mom)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with MOMENTUM = 0.950000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.8246 - accuracy: 0.3497 - val_loss: 1.7101 - val_accuracy: 0.3731
# Epoch 2/5
# 50000/50000 [==============================] - 10s 202us/step - loss: 1.5987 - accuracy: 0.4338 - val_loss: 1.5718 - val_accuracy: 0.4288
# Epoch 3/5
# 50000/50000 [==============================] - 10s 209us/step - loss: 1.5069 - accuracy: 0.4660 - val_loss: 1.6337 - val_accuracy: 0.4324
# Epoch 4/5
# 50000/50000 [==============================] - 10s 209us/step - loss: 1.4504 - accuracy: 0.4850 - val_loss: 1.6360 - val_accuracy: 0.4351
# Epoch 5/5
# 50000/50000 [==============================] - 10s 210us/step - loss: 1.3983 - accuracy: 0.5013 - val_loss: 1.4511 - val_accuracy: 0.4847
# Experiment with MOMENTUM = 0.850000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 10s 207us/step - loss: 1.8893 - accuracy: 0.3256 - val_loss: 1.7460 - val_accuracy: 0.3711
# Epoch 2/5
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.6894 - accuracy: 0.4024 - val_loss: 1.7721 - val_accuracy: 0.3681
# Epoch 3/5
# 50000/50000 [==============================] - 10s 200us/step - loss: 1.6014 - accuracy: 0.4346 - val_loss: 1.6198 - val_accuracy: 0.4175
# Epoch 4/5
# 50000/50000 [==============================] - 10s 197us/step - loss: 1.5443 - accuracy: 0.4549 - val_loss: 1.6835 - val_accuracy: 0.3951
# Epoch 5/5
# 50000/50000 [==============================] - 10s 199us/step - loss: 1.4958 - accuracy: 0.4727 - val_loss: 1.5458 - val_accuracy: 0.4508
# Experiment with MOMENTUM = 0.750000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 10s 207us/step - loss: 1.9273 - accuracy: 0.3093 - val_loss: 1.8464 - val_accuracy: 0.3431
# Epoch 2/5
# 50000/50000 [==============================] - 11s 211us/step - loss: 1.7440 - accuracy: 0.3849 - val_loss: 1.7071 - val_accuracy: 0.3912
# Epoch 3/5
# 50000/50000 [==============================] - 10s 203us/step - loss: 1.6604 - accuracy: 0.4122 - val_loss: 1.6521 - val_accuracy: 0.4035
# Epoch 4/5
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.6020 - accuracy: 0.4348 - val_loss: 1.6990 - val_accuracy: 0.3886
# Epoch 5/5
# 50000/50000 [==============================] - 10s 207us/step - loss: 1.5539 - accuracy: 0.4512 - val_loss: 1.5724 - val_accuracy: 0.4440

# %%
# nesterov = False
for mom in MOMENTUM:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with MOMENTUM = %.2f" % (mom))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=False, momentum=mom)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-MOMENTUM-no_nesterov-%s" % str(mom)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with MOMENTUM = 0.95
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 9s 181us/step - loss: 1.9037 - accuracy: 0.3116 - val_loss: 1.7363 - val_accuracy: 0.3696
# Epoch 2/5
# 50000/50000 [==============================] - 9s 182us/step - loss: 1.6785 - accuracy: 0.4003 - val_loss: 1.6394 - val_accuracy: 0.4062
# Epoch 3/5
# 50000/50000 [==============================] - 9s 175us/step - loss: 1.5866 - accuracy: 0.4312 - val_loss: 1.5870 - val_accuracy: 0.4241
# Epoch 4/5
# 50000/50000 [==============================] - 9s 187us/step - loss: 1.5348 - accuracy: 0.4527 - val_loss: 1.5292 - val_accuracy: 0.4512
# Epoch 5/5
# 50000/50000 [==============================] - 9s 181us/step - loss: 1.4901 - accuracy: 0.4694 - val_loss: 1.4878 - val_accuracy: 0.4732
# Experiment with MOMENTUM = 0.85
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 9s 181us/step - loss: 1.9191 - accuracy: 0.3123 - val_loss: 1.7566 - val_accuracy: 0.3663
# Epoch 2/5
# 50000/50000 [==============================] - 9s 188us/step - loss: 1.7022 - accuracy: 0.3977 - val_loss: 1.6735 - val_accuracy: 0.4012
# Epoch 3/5
# 50000/50000 [==============================] - 9s 186us/step - loss: 1.6147 - accuracy: 0.4284 - val_loss: 1.5916 - val_accuracy: 0.4345
# Epoch 4/5
# 50000/50000 [==============================] - 9s 187us/step - loss: 1.5558 - accuracy: 0.4468 - val_loss: 1.5128 - val_accuracy: 0.4567
# Epoch 5/5
# 50000/50000 [==============================] - 9s 180us/step - loss: 1.5052 - accuracy: 0.4672 - val_loss: 1.4759 - val_accuracy: 0.4736
# Experiment with MOMENTUM = 0.75
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 9s 186us/step - loss: 1.9182 - accuracy: 0.3141 - val_loss: 1.8022 - val_accuracy: 0.3641
# Epoch 2/5
# 50000/50000 [==============================] - 9s 181us/step - loss: 1.7208 - accuracy: 0.3898 - val_loss: 1.6731 - val_accuracy: 0.4091
# Epoch 3/5
# 50000/50000 [==============================] - 9s 188us/step - loss: 1.6395 - accuracy: 0.4204 - val_loss: 1.6322 - val_accuracy: 0.4118
# Epoch 4/5
# 50000/50000 [==============================] - 9s 188us/step - loss: 1.5805 - accuracy: 0.4419 - val_loss: 1.5915 - val_accuracy: 0.4359
# Epoch 5/5
# 50000/50000 [==============================] - 9s 180us/step - loss: 1.5413 - accuracy: 0.4547 - val_loss: 1.5541 - val_accuracy: 0.4476

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# 這個資料集下，有使用nesterov的效果較佳，且momentum設置越大越好。
